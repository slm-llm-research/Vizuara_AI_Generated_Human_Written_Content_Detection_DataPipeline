# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
raid_train_path = '/Users/mle/Documents/MLEngineering/Vizuara_LLMResearch/Week2_V2/dataset/raid/raid_train.csv'
raid_extra_path = '/Users/mle/Documents/MLEngineering/Vizuara_LLMResearch/Week2_V2/dataset/raid/raid_extra.csv'

raid_train = pd.read_csv(raid_train_path)
raid_extra = pd.read_csv(raid_extra_path)
raid_extra_code = raid_extra[raid_extra['domain'] == 'code']

# %%
raid_extra_path = '/Users/mle/Documents/MLEngineering/Vizuara_LLMResearch/Week2_V2/dataset/raid/raid_extra.csv'
raid_extra = pd.read_csv(raid_extra_path)
raid_extra_code = raid_extra[raid_extra['domain'] == 'code']

# %%
raid_extra_code.head()
# Out:
#                                      id                         adv_source_id  \
# 0  525a4452-faa9-4c02-a63e-926c1050a313  525a4452-faa9-4c02-a63e-926c1050a313
# 1  95d79f65-89e2-4bd2-93be-5c3ed995e485  95d79f65-89e2-4bd2-93be-5c3ed995e485
# 2  90001d71-d7b2-4982-b531-676a399bb848  90001d71-d7b2-4982-b531-676a399bb848
# 3  bd793d97-9023-41c8-94ba-4a38a1aa70e8  bd793d97-9023-41c8-94ba-4a38a1aa70e8
# 4  f800a5e8-ee78-420b-9285-b3fd8ab9c319  f800a5e8-ee78-420b-9285-b3fd8ab9c319
#
#                               source_id  model decoding repetition_penalty  \
# 0  525a4452-faa9-4c02-a63e-926c1050a313  human      NaN                NaN
# 1  95d79f65-89e2-4bd2-93be-5c3ed995e485  human      NaN                NaN
# 2  90001d71-d7b2-4982-b531-676a399bb848  human      NaN                NaN
# 3  bd793d97-9023-41c8-94ba-4a38a1aa70e8  human      NaN                NaN
# 4  f800a5e8-ee78-420b-9285-b3fd8ab9c319  human      NaN                NaN
#
# ...

# %%
raid_dataset = pd.concat([raid_train, raid_extra_code])

# %%
raid_dataset[raid_dataset['domain'] == 'code']

# %%
raid_dataset.groupby('domain')['model'].value_counts().reset_index().to_csv('/Users/mle/Documents/MLEngineering/Vizuara_LLMResearch/Week2_V2/dataset/raid_distribution.csv')

# %%
raid_distribution_path = '/Users/mle/Documents/MLEngineering/Vizuara_LLMResearch/Week2_V2/dataset/raid_distribution.csv'
raid_distribution = pd.read_csv(raid_distribution_path)

# %%
raid_distribution[raid_distribution['domain'] == 'code']
# Out:
#     Unnamed: 0 domain         model  count
# 24          24   code          gpt2  44160
# 25          25   code    llama-chat  44160
# 26          26   code       mistral  44160
# 27          27   code  mistral-chat  44160
# 28          28   code           mpt  44160
# 29          29   code      mpt-chat  44160
# 30          30   code       chatgpt  22080
# 31          31   code        cohere  22080
# 32          32   code   cohere-chat  22080
# 33          33   code          gpt3  22080
# 34          34   code          gpt4  22080
# 35          35   code         human  11040

# %%
raid_dataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 raid_dataset.head()
#
# NameError: name 'raid_dataset' is not defined

# %%
arxiv_dataset = pd.read_csv('/Users/mle/Documents/MLEngineering/Vizuara_LLMResearch/Week2_V2/dataset/arxiv-abstracts-2021/csv/train.csv')
# Out:
# /var/folders/v1/9ry4zkbd1v161tw5k5d51kk80000gn/T/ipykernel_4855/1621968660.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   arxiv_dataset = pd.read_csv('/Users/mle/Documents/MLEngineering/Vizuara_LLMResearch/Week2_V2/dataset/arxiv-abstracts-2021/csv/train.csv')

# %%
arxiv_dataset.head()
# Out:
#          id           submitter  \
# 0  704.0001      Pavel Nadolsky
# 1  704.0002        Louis Theran
# 2  704.0003         Hongjun Pan
# 3  704.0004        David Callan
# 4  704.0005  Alberto Torchinsky
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
# 3                                       David Callan
# 4           Wael Abu-Shammala and Alberto Torchinsky
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# ...

# %%
arxiv_dataset.shape
# Out:
# (1999486, 11)
